# %% [markdown]
# <a href="https://colab.research.google.com/github/Eliezer1995385/ACTIVIDADES-Y-PIA-1995385/blob/main/OPCION%204%20JUEGO%20DE%20ADIVIANSA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# EjercicioPython_1 ELIEZER RICARDO HERRERA OLIVA 1995385
import math
import sys
import random

print(" HOLA ELIEZER RICARDO HERRERA OLIVA 1995385 N2 IAyRN ")
print("Hola, porfavor escoge una opcion\n1-Saludo con tu nombre\n2-Inversion de una lista de elementos\n3-Serie Fibonacci\n4-Juego de adivinansa\n5-Numeros primos\n6-Calculadora basica\n")
opcion=int(input("Escoja una opcion\n "))

if opcion==1:
  nombre=input("Introduzca su nombre:")
  nombres_excluidos={'Ana','Juan','Pedro'}
  if nombre in nombres_excluidos:
      print("Este nombre no esta permitido")
  else:
      print("Hola",nombre,"!")

if opcion==2:
   DATOS=input("Ingrese la cantidad de datos que quiere guardar")
   DATOS=int(DATOS)
   i=0
   VALORES=[]
   while i<DATOS:

     VALOR=input("Introduzca el valor del elemento {}: ".format(i))
     VALORES.append(VALOR)
     i=i+1
   print("Los elementos que intrudjo fueron:",VALORES)
   Invertidos=VALORES[::-1]
   print("Los elementos invertidos son ",Invertidos)

if opcion==3:
   VALORES=input("Cuantos numeros de la serie Fibonacci quieres imprimir?: ")
   VALORES=int(VALORES)
   Num_Fib=[]
   contador=0
   j=0
   i=1

   while contador<VALORES:
      FIBO=j+i
      Num_Fib.append(FIBO)
      j=i
      i=FIBO
      contador=contador+1

   if contador==VALORES:
    print("Los numeros de la serie Fibonacci son ",Num_Fib)

if opcion==4:
    VALOR=int(input("introduzca un numero entre 1 y 100: "))
    numero=random.randint(1,100)

    while VALOR!=numero:

     if VALOR>numero:
       print("El numero que introdujo es mayor al que se genero")
       VALOR=int(input("introduzca un numero entre 1 y 100: "))
     elif VALOR<numero:
       print("El numero que introdujo es menor al que se genero")
       VALOR=int(input("introduzca un numero entre 1 y 100: "))
print("Felicidades, adivino el numero, el numero generado fue ",numero)

if opcion==5:
    VALOR=int(input("ingrese cuantos numeros primos quiere imprimir: "))
    i=0
    j=2
    Num_Primos=[]

    while  VALOR!=i:
       if j==2 :
        Num_Primos.append(j)
        i=i+1
        j=j+1
       if j%2==0:
        j=j+1
       if j%2!=0:
        Num_Primos.append(j)
        i=i+1
        j=j+1
    print("Los numeros primos encontrados fueron",Num_Primos)

if opcion==6:
   OPCIONES=int(input("Introduzca la operaicon que quiera realizar:\n1-Suma\n2-Resta\n3-Multiplicacion\n4-Division\n"))
   if OPCIONES==1:
    a=int(input("Introduzca el primer numero: "))
    b=int(input("Introduzca el segundo numero:"))
    suma=a+b
    print("La suma de los numeros es ",suma)

   if OPCIONES==2:
    a=int(input("Introduzca el primer numero: "))
    b=int(input("Introduzca el segundo numero:"))
    resta=a-b
    print("La resta de los numeros es ",resta)

   if OPCIONES==3:
    a=int(input("Introduzca el primer numero: "))
    b=int(input("Introduzca el segundo numero:"))
    mult=a*b
    print("La multiplicacion de los numeros es ",mult)

   if OPCIONES==4:
    a=int(input("Introduzca el primer numero: "))
    b=int(input("Introduzca el segundo numero:"))
    div=a/b
    print("La division de los numeros es ",div)
# Out:
#  HOLA ELIEZER RICARDO HERRERA OLIVA 1995385 N2 IAyRN
# Hola, porfavor escoge una opcion
# 1-Saludo con tu nombre
# 2-Inversion de una lista de elementos
# 3-Serie Fibonacci
# 4-Juego de adivinansa
# 5-Numeros primos
# 6-Calculadora basica
#
# Escoja una opcion
#  4
# introduzca un numero entre 1 y 100: 5
# El numero que introdujo es menor al que se genero
# introduzca un numero entre 1 y 100: 60
# El numero que introdujo es mayor al que se genero
# introduzca un numero entre 1 y 100: 50
# El numero que introdujo es menor al que se genero
# introduzca un numero entre 1 y 100: 55
# El numero que introdujo es menor al que se genero
# introduzca un numero entre 1 y 100: 57
# El numero que introdujo es menor al que se genero
# introduzca un numero entre 1 y 100: 58
# El numero que introdujo es menor al que se genero
# introduzca un numero entre 1 y 100: 59
# Felicidades, adivino el numero, el numero generado fue  59
